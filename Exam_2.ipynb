# %% [markdown]
# <a href="https://colab.research.google.com/github/Arisarayangyoo/Python_dataviz2024/blob/main/Exam_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import os
person_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/person.csv')
interview_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/interview.csv')
income_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/income.csv')
get_fit_now_member_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/get_fit_now_member.csv')
get_fit_now_check_in_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/get_fit_now_check_in.csv')
facebook_event_checkin_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/facebook_event_checkin.csv')
driver_license_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/drivers_license.csv')
crime_scene_report_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/crime_scene_report.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#person.csv ข้อมูลประชากร
person_df.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
#interview.csv ข้อมูลการสอบสวน
interview_df.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
#income.csv ข้อมูลรายได้
income_df.head()
# Out:
#          ssn  annual_income
# 0  100009868          52200
# 1  100169584          64500
# 2  100300433          74400
# 3  100355733          35900
# 4  100366269          73000

# %%
#get_fit_now_member.csv ข้อมูลสมาชิก ฟิตเนส Get Fit Now
get_fit_now_member_df.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
#get_fit_now_check_in.csv ข้อมูลการเข้าใช้ ฟิตเนส Get Fit Now
get_fit_now_check_in_df.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
#facebook_event_checkin.csv ข้อมูลการเช็คอิน Facebook
facebook_event_checkin_df.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %%
#driver_license.csv ข้อมูลใบขับขี่
driver_license_df.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
#crime_scene_report.csv ข้อมูลคดี
crime_scene_report_df
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %% [markdown]
# #ให้สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City โดยเริ่มจากการตรวจสอบ ข้อมูลคดี (crime_scene_report.csv)

# %%
# เลือกเฉพาะ type murder and date 20180115 ที่ SQL City

witness = crime_scene_report_df[(crime_scene_report_df.type == 'murder') & (crime_scene_report_df.date == 20180115) & (crime_scene_report_df.city == 'SQL City')]
witness
#ได้ข้อมูลว่า"กล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน คนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน 'Northwestern Dr'. พยานคนที่สอง ซึ่งชื่อว่า Annabel อาศัยอยู่ที่ไหนสักแห่งบนถนน 'Franklin Ave'"
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %% [markdown]
# ##ตามหาพยานคนที่ 1

# %%
#พยานคนที่ 1 คนที่อยู่บ้านหลังสุดท้ายบนถนน 'Northwestern Dr'
witness1 = person_df[person_df.address_street_name == 'Northwestern Dr'].sort_values('address_number', ascending = False).iloc[0]
witness1
# Out:
# id                               14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# Name: 499, dtype: object

# %%
#เช็คข้อมูลการสอบสวนของพยานคนที่1
interview_df[interview_df.person_id == 14887]


"""
จากการสืบสวนพบว่า"พยานได้ยินเสียงปืนแล้วเห็นผู้ชายคนหนึ่งวิ่งออกมา เขาถือกระเป๋าจาก 'Get Fit Now Gym'
หมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย '48Z' ซึ่งหมายความว่าเขาเป็นสมาชิกระดับทอง ผู้ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร 'H42W'"
"""
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %% [markdown]
# ##ตามหาพยานคนที่ 2

# %%
#พยานคนที่ 2 คนที่ชื่อ Annabel และอาศัยอยู่บนถนน 'Franklin Ave'
witness2 = person_df[person_df['name'].str.contains("Annabel")& (person_df.address_street_name == 'Franklin Ave')]
witness2
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
#เช็คข้อมูลการสอบสวนของพยานคนที่ 2
interview_df[interview_df.person_id == 16371]

"""
จากการสืบสวนพบว่า"พยานเห็นการฆาตกรรมเกิดขึ้น และฉันจำคนร้ายได้ออกจากฟิตเนสของเขาเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม"

"""
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# ## ตามหาฆาตรกร

# %%
#คนที่มี id ขึ้นต้นด้วย 48Z และอยู่ระดับ gold
suspert = get_fit_now_member_df[get_fit_now_member_df['id'].str.contains("48Z")& (get_fit_now_member_df.membership_status == 'gold' )]
suspect
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# ##ผู้ต้องหาคนที่ 1 Jeremy Bowers

# %%
#ข้อมูลการเข้าฟิตเนตผู้ต้องหาคนที่ 1 Jeremy Bowers
suspect1 = get_fit_now_check_in_df[get_fit_now_check_in_df.membership_id   == '48Z55']
suspect1
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2701         48Z55       20180109           1530            1700

# %% [markdown]
# ##ผู้ต้องหาคนที่ 2 Joe Germuska

# %%
#ข้อมูลการเข้าฟิตเนตผู้ต้องหาคนที่ 2 Joe Germuska
suspect1 = get_fit_now_check_in_df[get_fit_now_check_in_df.membership_id   == '48Z7A']
suspect1
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730

# %%
#ผู้ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร 'H42W'
suspect = driver_license_df[driver_license_df['plate_number'].str.contains('H42W')& (driver_license_df.gender == 'male')]
suspect
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 6240  664760   21      71     black      black   male       4H42WR     Nissan
#
#      car_model
# 3529  Spark LS
# 6240    Altima

# %%
person_df[person_df.license_id == 423327]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %%
person_df[person_df.license_id == 664760]
# Out:
#          id            name  license_id  address_number address_street_name  \
# 4664  51739  Tushar Chandra      664760             312              Phi St
#
#             ssn
# 4664  137882671

# %% [markdown]
# ## Jeremy Bowers

# %%
#คำให้การของผู้ต้องหา
interview_df[interview_df.person_id == 67318]

"""
ผู้ต้องหาให้การสารภาพว่า "เขาถูกจ้างโดยผู้หญิงที่มีเงินมาก ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอเข้าร่วมคอนเสิร์ต SQL Symphony ถึง 3 ครั้งในเดือนธันวาคม 2017"
"""
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# ##หาตัวผู้จ้างวานฆ่า
# """
# ผู้ต้องหาให้การสารภาพว่า "เขาถูกจ้างโดยผู้หญิงที่มีเงินมาก ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว)
# เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอเข้าร่วมคอนเสิร์ต SQL Symphony ถึง 3 ครั้งในเดือนธันวาคม 2017"
# """

# %%
Contractor = driver_license_df[(driver_license_df.gender == 'female')&(driver_license_df.hair_color == 'red')&(driver_license_df.car_make == 'Tesla')&(driver_license_df.car_model == 'Model S')]
Contractor
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %% [markdown]
# ##ผู้ต้องหาคนที่ 1 Miranda Priestly

# %%
Contractor1 = person_df[person_df.license_id == 202298]
Contractor1
# Out:
#          id              name  license_id  address_number address_street_name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             ssn
# 9985  987756388

# %%
facebook_event_checkin_df[facebook_event_checkin_df.person_id == 99716]
# Out:
#        person_id  event_id            event_name      date
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229

# %% [markdown]
# ##ผู้ต้องหาคนที่ 2 Regina George

# %%
Contractor2 = person_df[person_df.license_id == 291182]
Contractor2
# Out:
#          id           name  license_id  address_number address_street_name  \
# 8977  90700  Regina George      291182             332           Maple Ave
#
#             ssn
# 8977  337169072

# %%
facebook_event_checkin_df[facebook_event_checkin_df.person_id == 90700]
# Out:
# Empty DataFrame
# Columns: [person_id, event_id, event_name, date]
# Index: []

# %% [markdown]
# ##ผู้ต้องหาคนที่ 3 Red Korb

# %%
Contractor3 = person_df[person_df.license_id == 918773]
Contractor3
# Out:
#          id      name  license_id  address_number address_street_name  \
# 7664  78881  Red Korb      918773             107         Camerata Dr
#
#             ssn
# 7664  961388910

# %%
facebook_event_checkin_df[facebook_event_checkin_df.person_id == 78881]
# Out:
# Empty DataFrame
# Columns: [person_id, event_id, event_name, date]
# Index: []

# %% [markdown]
# ## Miranda Priestly

# %%
#ค่าเฉลี่ยรายได้(ไม่เอาทศนิยม)
income_df['annual_income'].describe().astype(int)
# Out:
# count      7514
# mean      53257
# std       38463
# min       10000
# 25%       30500
# 50%       50800
# 75%       70800
# max      498500
# Name: annual_income, dtype: int64

# %%
income_df[income_df.ssn == 987756388]
#คำให้การของฆาตรกรบอกว่าผู้ว่าจ้างรวยมาก
# Out:
#             ssn  annual_income
# 7422  987756388         310000

# %%
interview_df[interview_df.person_id == 99716]
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []
